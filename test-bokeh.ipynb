# %%
import numpy as np

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3c6dedbf-41a4-4feb-9a94-93280fcdb400">Loading BokehJS ...</span>
#     </div>

# %%
N = 300
x = np.linspace(0, 4*np.pi, N)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
source = ColumnDataSource(data=dict(x=x, y1=y1, y2=y2))

# %%
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"

s1 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s1.scatter('x', 'y1', source=source)

# Linked brushing in Bokeh is expressed by sharing data sources between
# renderers. Note below that s2.scatter is called with the `source` 
# keyword argument, and supplied with the same data source from s1.scatter
s2 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s2.circle('x', 'y2', source=source)
# Out:
# GlyphRenderer(id='3680dd9a-c607-4194-b6a9-af8953a3090c', ...)

# %%
p = gridplot([[s1,s2]])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fc8cebd8-4f75-40a1-88ed-aa53b98619a3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fc8cebd8-4f75-40a1-88ed-aa53b98619a3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc8cebd8-4f75-40a1-88ed-aa53b98619a3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc8cebd8-4f75-40a1-88ed-aa53b98619a3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dae09862-fc32-48ab-8194-c93c2e26f374":{"roots":{"references":[{"attributes":{"plot":{"id":"c45cc2d2-0190-4c14-96eb-87eb9d17b72d","subtype":"Figure","type":"Plot"}},"id":"bc7eaae6-1b3a-4ea6-bfd7-4f431713e30a","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y1"}},"id":"1962f380-f57f-4084-b31c-d5b6ed9a4c54","type":"Circle"},{"attributes":{"children":[{"id":"e03d3160-ed83-4811-81b7-dac6a9a39b2e","type":"Row"}]},"id":"9192c98f-941d-4ddf-91bd-a592d5c2a784","type":"Column"},{"attributes":{"plot":{"id":"c45cc2d2-0190-4c14-96eb-87eb9d17b72d","subtype":"Figure","type":"Plot"}},"id":"d60bd150-352d-41a3-b404-f617e72f4066","type":"PanTool"},{"attributes":{},"id":"e886ce31-ffae-4332-97dc-aae1e05e6ad0","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"de13a72d-929b-4b45-8f65-8b0be193bdac","type":"BoxAnnotation"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"d60bd150-352d-41a3-b404-f617e72f4066","type":"PanTool"},{"id":"525c5b7f-8e7e-45ae-b622-b71ef643b144","type":"WheelZoomTool"},{"id":"79030210-e198-4da1-9a0d-7725f63232a7","type":"BoxZoomTool"},{"id":"bc7eaae6-1b3a-4ea6-bfd7-4f431713e30a","type":"ResetTool"},{"id":"940fb9c4-d403-45c5-b7ba-6ec7bdb4152f","type":"SaveTool"},{"id":"2e1ae30c-2a2b-498f-997f-6553f01cdcf0","type":"BoxSelectTool"},{"id":"41c76eda-7a81-4eb3-aff9-1c2a5db9059a","type":"LassoSelectTool"},{"id":"3190e6a3-908b-4b25-b8c8-8e232e48d176","type":"PanTool"},{"id":"d7c0fefc-c8e4-470b-9568-b989b1a22fc5","type":"WheelZoomTool"},{"id":"9cf13b30-165a-4428-9339-3e9c700fe905","type":"BoxZoomTool"},{"id":"a7f434bd-a0be-4a7d-92ec-a2901f7eacfd","type":"ResetTool"},{"id":"9d0fd49f-9932-4037-9063-d08271ad9860","type":"SaveTool"},{"id":"5212d150-1646-4c1d-84f1-62ee5bbda030","type":"BoxSelectTool"},{"id":"668681d4-f970-4bc9-8c56-fb10669c1df6","type":"LassoSelectTool"}]},"id":"d6d0c4f5-ae7b-4681-8a82-0e1a3142b442","type":"ToolbarBox"},{"attributes":{"plot":{"id":"64f741dc-2c39-44ab-a6d6-80c7d2c329e0","subtype":"Figure","type":"Plot"}},"id":"9d0fd49f-9932-4037-9063-d08271ad9860","type":"SaveTool"},{"attributes":{},"id":"23aebf49-519b-4e09-93d7-4faf7f614961","type":"ToolEvents"},{"attributes":{"formatter":{"id":"e886ce31-ffae-4332-97dc-aae1e05e6ad0","type":"BasicTickFormatter"},"plot":{"id":"c45cc2d2-0190-4c14-96eb-87eb9d17b72d","subtype":"Figure","type":"Plot"},"ticker":{"id":"b43bc3ff-7b97-45cf-a663-8a2ce26688ea","type":"BasicTicker"}},"id":"67c85562-dc59-4799-8eb2-1fc5dd64d118","type":"LinearAxis"},{"attributes":{"formatter":{"id":"6896ab5c-0b79-43ef-8ea0-6dcac8e6e16f","type":"BasicTickFormatter"},"plot":{"id":"64f741dc-2c39-44ab-a6d6-80c7d2c329e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"b7e28a00-8b3f-4dd5-b080-08db62b59637","type":"BasicTicker"}},"id":"2de9ac6d-c825-465b-8814-c07a87f0cee6","type":"LinearAxis"},{"attributes":{"callback":null},"id":"a82f292e-7ca9-4c30-b337-cd9ed017b6b5","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"53f36b33-df59-4603-b8db-e0821dbde8cb","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"e8bbe1e1-4dac-42be-8507-47f95b49e9f2","type":"ColumnDataSource"},"glyph":{"id":"56534148-9a41-4232-9197-a767c45270bc","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4c6995f9- ...

# %%
N = 4000

# %%
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e18e4133-1f32-474b-b0d2-623f070182b2">Loading BokehJS ...</span>
#     </div>

# %%
TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,tap,previewsave,box_select,poly_select,lasso_select"

p = figure(tools=TOOLS)
p.scatter(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
# Out:
# GlyphRenderer(id='25dcf07a-f780-43cf-8564-fcd2249896a3', ...)

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8098e6cc-befb-4177-b009-73a92fec94c6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8098e6cc-befb-4177-b009-73a92fec94c6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8098e6cc-befb-4177-b009-73a92fec94c6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8098e6cc-befb-4177-b009-73a92fec94c6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"04c7cade-af9f-4282-b863-8b5ac4db6efb":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"03c2581b-d26a-4206-a495-628c63ebf912","type":"PolyAnnotation"},{"attributes":{"plot":null,"text":""},"id":"4e6eca47-ab60-4871-a83c-7784598e5d3f","type":"Title"},{"attributes":{},"id":"425b6d41-f690-4852-9d9e-60992ab65431","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"23de664e-4dd5-4969-8804-55e5c4554b82","subtype":"Figure","type":"Plot"}},"id":"6e1f8cdb-e23d-4cc8-8f28-e9196394ce95","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"15d0a75e-2d2a-4e70-8fc1-9b32c6696203","type":"ResizeTool"},{"id":"a924445a-3d26-4252-94f0-a1e3843f86d4","type":"CrosshairTool"},{"id":"2e503476-3f4a-47c1-87ae-2d4d6a19d8f9","type":"PanTool"},{"id":"520ccaef-8017-4048-a930-4001e0024bdb","type":"WheelZoomTool"},{"id":"75a37597-cc80-49c3-ba4f-cefce36fe7b5","type":"BoxZoomTool"},{"id":